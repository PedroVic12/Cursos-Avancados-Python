# %% [markdown]
# https://matplotlib.org/stable/index.html
#
# Video com tutorial: https://www.youtube.com/watch?v=wB9C0Mz9gSo&t=1757s

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# <img src = "matplotlib.png" width = 500 height = 400>

# %% [markdown]
# ### **Gráfico Simples**:

# %%
x = [1,2,3,4]
y = [3,4,5,6]
plt.plot(x, y)
plt.show()

# %%
x = [1, 2, 3, 4]
y = [3, 4, 5, 6]
plt.plot(x, y, label = "dados")


#EIXOS
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')

#Mudança de escala
plt.title("Titulo do grafico")
plt.xticks([0,2,4,5,8])
plt.yticks([-1,3,5,9,11])

#Valor da legenda
plt.legend()

plt.show()

# %% [markdown]
# #### Estilizando

# %%
plt.plot(x,y, linestyle = "--", color='red')

# %%
x1 = np.linspace(0,5,10)
y1 = x1**2
plt.plot(x1,y1)

#Titulo:
plt.title("Titulo do gráfico")

#Eixos:
plt.xlabel("Eixo X")
plt.ylabel("Eixo Y")
# Out:
# Text(0, 0.5, 'Eixo Y')

# %% [markdown]
# ### **Vários gráficos juntos** (Subplots)

# %%
valores_x = [1.2,4,5]
valores_y = [1.4,3,2]

# Grafico 1:
figura = plt.figure(figsize=(20,8))
figura.suptitle("Titulo geral") 
figura.add_subplot(131)
plt.plot(valores_x, valores_y, label='Um dado qualquer')
plt.legend()
plt.title("Grafico 1")

#Grafico 2:
figura.add_subplot(132)
plt.bar(valores_x, valores_y)
plt.title("Grafico 2")

#Grafico 3:    
figura.add_subplot(133)  # (1 linha, 3 coluna, 3 posição)
plt.scatter(valores_x, valores_y)
plt.title('Grafico 3')


plt.show(figura)

# %% [markdown]
# ### **Usando Figuras como objetos**

# %%
#Criando figuras
fig_1 = plt.figure(figsize=(5,4),dpi=100)
axes_1 = fig_1.add_axes([0.1,0.1,0.9,0.9])

#Primeiro gráfico
axes_1.set_xlabel('Days')
axes_1.set_ylabel('Days squared')
axes_1.set_title('Titulo')
axes_1.plot(x1,y1,label='x/x2')
axes_1.plot(y1,x1,label='x2/x')
axes_1.legend(loc=0)


#Segundo Gráfico
axes_2 = fig_1.add_axes([0.45,0.45,0.4,0.3])
axes_2.set_xlabel('Days')
axes_2.set_ylabel('Days squared')
axes_2.set_title('Titulo')
axes_2.plot(x1,y1,label='x/x2')

axes_2.text(0,40,"TEXTO TESTE",color='red')
# Out:
# Text(0, 40, 'TEXTO TESTE')

# %% [markdown]
# ### **Aplicação Real com pandas**

# %%
import pandas as pd

# %%
exemplo_df = pd.read_csv("indexData.csv")
display(exemplo_df)
# Out:
#        Index        Date         Open         High          Low        Close  \
# 0        NYA  1965-12-31   528.690002   528.690002   528.690002   528.690002
# 1        NYA  1966-01-03   527.210022   527.210022   527.210022   527.210022
# 2        NYA  1966-01-04   527.840027   527.840027   527.840027   527.840027
# 3        NYA  1966-01-05   531.119995   531.119995   531.119995   531.119995
# 4        NYA  1966-01-06   532.070007   532.070007   532.070007   532.070007
# ...      ...         ...          ...          ...          ...          ...
# 112452  N100  2021-05-27  1241.119995  1251.910034  1241.119995  1247.069946
# 112453  N100  2021-05-28  1249.469971  1259.209961  1249.030029  1256.599976
# 112454  N100  2021-05-31  1256.079956  1258.880005  1248.140015  1248.930054
# 112455  N100  2021-06-01  1254.609985  1265.660034  1254.609985  1258.579956
# 112456  N100  2021-06-02  1258.489990  1263.709961  1258.239990  1263.619995
#
#           Adj Close       Volume
# ...

# %% [markdown]
# - Buscando so a bolsa de nova york (NYA)
#
# - data de fechamento

# %%
exemplo_df2 = exemplo_df[['Index', 'Date','Open']]
display(exemplo_df2)
# Out:
#        Index        Date         Open
# 0        NYA  1965-12-31   528.690002
# 1        NYA  1966-01-03   527.210022
# 2        NYA  1966-01-04   527.840027
# 3        NYA  1966-01-05   531.119995
# 4        NYA  1966-01-06   532.070007
# ...      ...         ...          ...
# 112452  N100  2021-05-27  1241.119995
# 112453  N100  2021-05-28  1249.469971
# 112454  N100  2021-05-31  1256.079956
# 112455  N100  2021-06-01  1254.609985
# 112456  N100  2021-06-02  1258.489990
#
# [112457 rows x 3 columns]

# %%
dfremove = exemplo_df2.loc[(exemplo_df['Index'] != 'NYA')]

cotacao_novaYork_df = exemplo_df2.drop(dfremove.index)

cotacao_novaYork_df = cotacao_novaYork_df[13900:]

display(cotacao_novaYork_df)
# Out:
#       Index        Date         Open
# 13900   NYA  2021-03-23  15551.58008
# 13901   NYA  2021-03-24  15346.53027
# 13902   NYA  2021-03-25  15276.55957
# 13903   NYA  2021-03-26  15410.37012
# 13904   NYA  2021-03-29  15682.54004
# 13905   NYA  2021-03-30  15611.87988
# 13906   NYA  2021-03-31  15626.11035
# 13907   NYA  2021-04-01  15601.74023
# 13908   NYA  2021-04-05  15752.24023
# 13909   NYA  2021-04-06  15870.33984
# 13910   NYA  2021-04-07  15877.95996
# 13911   NYA  2021-04-08  15838.84961
# 13912   NYA  2021-04-09  15886.55957
# 13913   NYA  2021-04-12  15956.37012
# 13914   NYA  2021-04-13  15977.45996
# 13915   NYA  2021-04-14  15962.33984
# 13916   NYA  2021-04-15  16000.15039
# 13917   NYA  2021-04-16  16116.84961
# 13918   NYA  2021-04-19  16186.29004
# 13919   NYA  2021-04-20  16107.55957
# 13920   NYA  2021-04-21  15944.61035
# 13921   NYA  2021-04-22  16121.61035
# 13922   NYA  2021-04-23  16030.62012
# 13923   NYA  2021-04-26  16206.00000
# ...

# %%
plt.figure(figsize=(20,4))
plt.plot(cotacao_novaYork_df['Date'], cotacao_novaYork_df['Open'],label = 'Cotações do dólar')
plt.legend(loc= 0, fontsize=18)
plt.ylabel('Valor do fechamento')
plt.xlabel('Data da cotação')
plt.title('Grafico de cotação da Bolsa de Nova York')
plt.xticks(['2021-03-23', '2021-04-23', '2021-05-23'])

plt.show()
